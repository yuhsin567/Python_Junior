# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.arange(0,2*np.pi,0.01)

c=2+np.cos(a)
s=np.sin(a)

c1=-2+np.cos(a)
s1=np.sin(a)

c2=+np.cos(a)
s2=-2+np.sin(a)

c3=np.cos(a)
s3=2+np.sin(a)

for r in range(1,11):
    plt.plot(r*c1,r*s1)
    plt.plot(r*c2,r*s2)
    plt.plot(r*c3,r*s3)
    plt.plot(r*c,r*s)

# %%
a = np.arange(0,2*np.pi,0.01)

c=-1.5+np.cos(a)
s=np.sin(a)

for r in range(1,11):
    
    plt.plot(r*c,r*s)


x=np.array([1,1,2,2,1])
y=np.array([1,2,2,1,1])

for n in range(1,11):
    plt.plot(n*x-0.5*n,n*y-1.5*n)

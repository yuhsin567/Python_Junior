# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.plot([5,1,3],[1,5,3])

# %%
plt.scatter([1,2],[5,6])

# %%
array=np.random.randn(5)
print type(array)
print array
# Out:
#   File "<ipython-input-13-0d89f4e26109>", line 2
#     print type(array)
#              ^
# SyntaxError: invalid syntax

# %%
array=np.random.randn(5)
plt.plot(array)
plt.scatter(array,[1,2,3,4,5,])

# %%
plt.figure()
